# %%
import pickle
import numpy as np
import pandas as pd
import seaborn as sns
import category_encoders as ce
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline,make_pipeline
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest,chi2
from sklearn.metrics import accuracy_score , confusion_matrix

# %%
df = pd.read_csv("Loan_Dataset.xlsx - Sheet1.csv")

# %%
df.head()
# Out:
#   Gender  Dependents     Education Self_Employed  ApplicantIncome  LoanAmount  \
# 0   Male         0.0      Graduate            No             5849         NaN
# 1   Male         1.0      Graduate            No             4583       128.0
# 2   Male         0.0      Graduate           Yes             3000        66.0
# 3   Male         0.0  Not Graduate            No             2583       120.0
# 4   Male         0.0      Graduate            No             6000       141.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
df.isnull().mean()*100>0
# Out:
# Gender              True
# Dependents          True
# Education          False
# Self_Employed       True
# ApplicantIncome    False
# LoanAmount          True
# Credit_History      True
# Property_Area      False
# Loan_Status        False
# dtype: bool

# %%
X = df.iloc[:, :-1]
y = df.iloc[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
trf1 = ColumnTransformer([
    ('impute_gender',SimpleImputer(strategy='most_frequent'),[0]),
    ('impute_Dependents',SimpleImputer(strategy='most_frequent'),[1]),
    ('impute_Self_Employed',SimpleImputer(strategy='most_frequent'),[3]),
    ('impute_Credit_History',SimpleImputer(strategy='most_frequent'),[6]),
    ('impute_LoanAmount',SimpleImputer(strategy='mean'),[5])
],remainder='passthrough')

# %%
# one hot encoding
trf2 = ColumnTransformer([
    ('ohe_gender',OneHotEncoder(sparse_output=False,handle_unknown='ignore'),[0,2,5]),
    ('ordinal_property',OrdinalEncoder(categories=[['Rural','Urban','Semiurban']]),[7])
],remainder='passthrough')

# %%
# Scaling
trf3 = ColumnTransformer([
    ('scale',MinMaxScaler(),slice(9)),
    ('standard',StandardScaler(),slice(8,10))
],remainder='passthrough')

# %%
clf = LogisticRegression()

# %% [markdown]
# # PIPELINE

# %%
pipe = Pipeline([
    ('trf1',trf1),
    ('trf2',trf2),
    ('trf3',trf3),
    ('clf',clf)
])

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('trf1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('impute_gender',
#                                                   SimpleImputer(strategy='most_frequent'),
#                                                   [0]),
#                                                  ('impute_Dependents',
#                                                   SimpleImputer(strategy='most_frequent'),
#                                                   [1]),
#                                                  ('impute_Self_Employed',
#                                                   SimpleImputer(strategy='most_frequent'),
#                                                   [3]),
#                                                  ('impute_Credit_History',
#                                                   SimpleImputer(strategy='most_frequent'),
#                                                   [6]),
#                                                  ('i...
#                                    transformers=[('ohe_gender',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   [0, 2, 5]),
#                                                  ('ordinal_property',
#                                                   OrdinalEncoder(categories=[['Rural',
#                                                                               'Urban',
#                                                                               'Semiurban']]),
#                                                   [7])])),
#                 ('trf3',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('scale', MinMaxScaler(),
#                                                   slice(None, 9, None)),
#                                                  ('standard', StandardScaler(),
#                                                   slice(8, 10, None))])),
#                 ('clf', LogisticRegression())])

# %%
# Predict
y_pred = pipe.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8048780487804879

# %% [markdown]
# # CROSS VALIDATION

# %%
# cross validation using cross_val_score
from sklearn.model_selection import cross_val_score
cross_val_score(pipe, X_train, y_train, cv=5, scoring='accuracy').mean()
# Out:
# 0.8086167800453514

# %% [markdown]
# # Pikle File

# %%
# export 
import pickle
pickle.dump(pipe,open('loan_file.pkl','wb'))

# %%
X
# Out:
#      Gender  Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male         0.0      Graduate            No             5849
# 1      Male         1.0      Graduate            No             4583
# 2      Male         0.0      Graduate           Yes             3000
# 3      Male         0.0  Not Graduate            No             2583
# 4      Male         0.0      Graduate            No             6000
# ..      ...         ...           ...           ...              ...
# 609  Female         0.0      Graduate            No             2900
# 610    Male         3.0      Graduate            No             4106
# 611    Male         1.0      Graduate            No             8072
# 612    Male         2.0      Graduate            No             7583
# 613  Female         0.0      Graduate           Yes             4583
#
#      LoanAmount  Credit_History Property_Area
# 0           NaN             1.0         Urban
# 1         128.0             1.0         Rural
# 2          66.0             1.0         Urban
# 3         120.0             1.0         Urban
# 4         141.0             1.0         Urban
# ..          ...             ...           ...
# 609        71.0             1.0         Rural
# 610        40.0             1.0         Rural
# 611       253.0             1.0         Urban
# 612       187.0             1.0         Urban
# 613       133.0             0.0     Semiurban
#
# [614 rows x 8 columns]
